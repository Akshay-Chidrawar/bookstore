-- %%
select * from bookstore.bronze.books
where book_id='B01';

select * from bookstore.silver.books
where book_id='B01';

select * from bookstore.bronze.books
where source_file='s3://bookstorerawdata/rawfeed/AK_booksUpdate_01.json';
